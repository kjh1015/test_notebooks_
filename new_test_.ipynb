# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

# Load environment variables
load_dotenv()

# Set up OpenAI API key
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
import ell

@ell.simple(model="gpt-4o")
def hello(world : str):
    """You are a helpful assistant that writes in lower case.""" # System Message
    return f"Say hello to {world[::-1]} with a poem."    # User Message

hello("sama")
# Out:
# "hello, dear amas, with joy i write,  \nto greet you warmly, in the morning light.  \nlike a gentle breeze that whispers by,  \ni send this note beneath the sky.  \n\nas sunbeams dance on fields of gold,  \nstories of wonder you've yet to be told.  \nyour presence is cherished, your smile so bright,  \nlike stars adorning the quiet night.  \n\nmay your day be filled with laughter and cheer,  \nwith love and kindness always near.  \nso here's my greeting, simple and true,  \na heartfelt hello, just for you.  "

# %%
import ell
import random

def get_random_adjective():
    adjectives = ["enthusiastic", "cheerful", "warm", "friendly"]
    return random.choice(adjectives)

@ell.simple(model="gpt-4o")
def hello(name: str):
    """You are a helpful assistant."""
    adjective = get_random_adjective()
    return f"Say a {adjective} hello to {name}!"

greeting = hello("Sam Altman")
print(greeting)
# Out:
# Hello, Sam Altman! I hope you're having a fantastic day. If there's anything you'd like to discuss or share, I'm here to help!

# %%
import ell
from typing import List

ell.init(verbose=True)


@ell.simple(model="gpt-4o-mini", temperature=1.0)
def generate_story_ideas(about : str):
    """You are an expert story ideator. Only answer in a single sentence."""
    return f"Generate a story idea about {about}."

@ell.simple(model="gpt-4o-mini", temperature=1.0)
def write_a_draft_of_a_story(idea : str):
    """You are an adept story writer. The story should only be 3 paragraphs."""
    return f"Write a story about {idea}."

@ell.simple(model="gpt-4o", temperature=0.1)
def choose_the_best_draft(drafts : List[str]):
    """You are an expert fiction editor."""
    return f"Choose the best draft from the following list: {'\n'.join(drafts)}."

@ell.simple(model="gpt-4-turbo", temperature=0.2)
def write_a_really_good_story(about : str):
    """You are an expert novelist that writes in the style of Hemmingway. You write in lowercase."""
    # Note: You can pass in api_params to control the language model call
    # in the case n = 4 tells OpenAI to generate a batch of 4 outputs.
    ideas = generate_story_ideas(about, api_params=(dict(n=4)))

    drafts = [write_a_draft_of_a_story(idea) for idea in ideas]

    best_draft = choose_the_best_draft(drafts)


    return f"Make a final revision of this story in your voice: {best_draft}."

story = write_a_really_good_story("a dog")
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║ generate_story_ideas(a dog)
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║ Prompt:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │      system: You are an expert story ideator. Only answer in a single
# │              sentence.
# │
# │        user: Generate a story idea about a dog.
# ╟──────────────────────────────────────────────────────────────────────────────╢
# ║ Output:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │   assistant: A shelter dog, overlooked for years, discovers an
# │              uncanny ability to sense emotions and begins helping its new
# │              owner, a grieving widower, reconnect with love and hope in their
# │              small town.
# ╚══════════════════════════════════════════════════════════════════════════════╝
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║ write_a_draft_of_a_story(A shelte..)
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║ Prompt:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │      system: You are an adept story writer. The story should only be 3
# │              paragraphs.
# │
# │        user: Write a story about A shelter dog, overlooked for years,
# │              discovers an uncanny ability to sense emotions and begins
# │              helping its new owner, a grieving widower, reconnect with
# │              love and hope in their small town..
# ╟──────────────────────────────────────────────────────────────────────────────╢
# ║ Output:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │   assistant
# │              with every adventure, Clara found her voice, while Rusty reveled
# │              in the companionship he had longed for beneath the stars.
# │
# │              Their escapades didn’t go unnoticed; the townsfolk
# │              grew curious about the unlikely pair. Clara’s sketches pulsating
# │              with life and Rusty’s street-smart antics captured the attention
# │              of others, weaving their lives into the fabric of the community
# │              once again. While unraveling the once-hidden stories of their
# │              town, Clara not only unearthed a treasure trove of history but
# │              also opened hearts, as friendships blossomed among the residents
# │              who had long since forgotten the joy of connection. Together,
# │              they celebrated the magic of discovery and camaraderie, proving
# │              that sometimes the greatest treasures are not gold coins or
# │              ancient artifacts, but the bonds we forge and the adventures we
# │              share.
# ╚══════════════════════════════════════════════════════════════════════════════╝
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║ write_a_draft_of_a_story(A stray ..)
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║ Prompt:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │      system: You are an adept story writer. The story should only be 3
# │              paragraphs.
# │
# │        user: Write a story about A stray dog with a unique ability to
# │              sense emotions teams up with a lonely child to help their
# │              small town heal from collective grief after a devastating
# │              event..
# ╟──────────────────────────────────────────────────────────────────────────────╢
# ║ Output:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │   assistant: In a quaint little town where the air was thick with
# │              sorrow, there roamed a stray dog named Leo, a shaggy brown mutt
# │              with soulful eyes that seemed to pierce through the darkest
# │              emotions. Leo possessed a unique ability: he could sense the
# │              feelings of those around him, a gift that had grown sharper in
# │              the wake of the town’s devastating tragedy. The community had
# │              suffered the loss of a beloved teacher, and the air was heavy
# │              with collective grief. As the townsfolk wandered through their
# │              daily routines, Leo made it his mission to help heal the broken
# │              hearts, believing the healing of one would ripple through the
# │              community.
# │
# │              One sunny afternoon, Leo's path crossed with a lonely
# │              child named Finn, who spent his days wandering the empty
# │              playgrounds and forgotten corners of the town. Finn, feeling the
# │              weight of sadness that wrapped around everyone like a thick fog,
# │              instantly felt a connection with Leo. The two formed an unlikely
# │              bond, and as they explored the town together, Leo would trot
# │              over to those in despair, gently nudging them with his nose.
# │              With each interaction, Finn learned to listen to the stories of
# │              those who had lost their spark, discovering that sharing their
# │              memories brought warmth back into their hearts, while sharing
# │              joyous moments brought laughter that echoed through the vacant
# │              streets.
# │
# │              Together, Finn and Leo became the heart of their town
# │              's healing. They organized small gatherings at the park, where
# │              townsfolk could come together to share memories of their lost
# │              teacher, play games, and enjoy one another's company. Slowly but
# │              surely, the grief began to lift, replaced by a growing sense of
# │              community and connection. As Finn and Leo sat on a favorite
# │              bench one evening, watching fireflies dance in the dusk, they
# │              both knew that the bond they had forged was stronger than any
# │              sorrow. They had not just helped the town heal, but had sparked
# │              a flame of hope that promised brighter days ahead—a testament
# │              that love, companionship, and shared memories could mend even
# │              the most broken of hearts.
# ╚══════════════════════════════════════════════════════════════════════════════╝
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║ write_a_draft_of_a_story(A lost d..)
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║ Prompt:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │      system: You are an adept story writer. The story should only be 3
# │              paragraphs.
# │
# │        user: Write a story about A lost dog, gifted with the ability to
# │              understand human speech, sets out on an adventurous quest
# │              across the city to reunite with its young owner who is
# │              heartbroken after their sudden separation..
# ╟──────────────────────────────────────────────────────────────────────────────╢
# ║ Output:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │   assistant
# │              thick fog, instantly felt a connection with Leo. The two
# │              formed an unlikely bond, and as they explored the town
# │              together, Leo would trot over to those in despair, gently
# │              nudging them with his nose. With each interaction, Finn
# │              learned to listen to the stories of those who had lost their
# │              spark, discovering that sharing their memories brought
# │              warmth back into their hearts, while sharing joyous moments
# │              brought laughter that echoed through the vacant streets.
# │              Together, Finn and Leo became the heart of their town's
# │              healing. They organized small gatherings at the park, where
# │              townsfolk could come together to share memories of their
# │              lost teacher, play games, and enjoy one another's company.
# │              Slowly but surely, the grief began to lift, replaced by a
# │              growing sense of community and connection. As Finn and Leo
# │              sat on a favorite bench one evening, watching fireflies
# │              dance in the dusk, they both knew that the bond they had
# │              forged was stronger than any sorrow. They had not just
# │              helped the town heal, but had sparked a flame of hope that
# │              promised brighter days ahead—a testament that love,
# │              companionship, and shared memories could mend even the most
# │              broken of hearts.
# │              Baxter, a scruffy golden retriever with kind, expressive
# │              eyes, felt a deep ache in his heart as he gazed up at the
# │              towering city skyline. Just hours before, he had been
# │              frolicking in the nearby park with his beloved young owner,
# │              Lily, when a sudden commotion had caused the two to become
# │              separated. Gifted with the extraordinary ability to
# │              understand human speech, Baxter could hear Lily's cries of
# │              despair echoing in his mind: “Baxter, where are you?”
# │              Determined to return to her, he set off through the bustling
# │              streets, weaving between towering buildings and dodging the
# │              feet of busy pedestrians.
# │              As he ventured further into the city, Baxter overheard
# │              snippets of conversation from friendly strangers who
# │              unknowingly offered him guidance. A cheerful barista shared,
# │              “I saw a little girl near the fountain at Central Park!”
# │              With his heart racing, Baxter dashed towards his
# │              destination, pawing through piles of autumn leaves that
# │              crunched beneath him. Along the way, he encountered a wise
# │              old alley cat, who encouraged him with a knowing nod. “Keep
# │              your ears open, pup! Sometimes, the right path is found in
# │              whispers of the wind.” Reinvigorated by the cat’s words,
# │              Baxter listened closely to his surroundings, tuning into the
# │              small voices of the city that felt like a map leading him
# │              home.
# │              After what seemed like an eternity of sniffing out clues and
# │              navigating through bustling restaurants and shops, Baxter
# │              finally reached Central Park, heart pounding with
# │              anticipation. As he approached the mesmerizing fountain, his
# │              eyes locked onto a small figure—a girl with pigtails and
# │              tear-stained cheeks, gazing forlornly at the water. With a
# │              burst of joy, Baxter barked, racing towards her at full
# │              speed. Time seemed to slow down as their eyes met, and in
# │              that moment, all pain and despair melted away. “Baxter!”
# │              Lily exclaimed, her voice a symphony of relief and joy. He
# │              leaped into her arms, his tail wagging fiercely, and
# │              together they reunited amidst the laughter of passing
# │              onlookers, their hearts full once more, thankful for the
# │              adventure that had brought them back together..
# ╟──────────────────────────────────────────────────────────────────────────────╢
# ║ Output:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │   assistant: The best draft is the first one. It presents a
# │              touching story of a scruffy shelter dog named Max who possesses
# │              a unique ability to sense emotions. The narrative explores the
# │              deep bond formed between Max and Henry, a grieving widower, and
# │              how Max's presence helps Henry heal and rediscover joy in life.
# │              The story is well-structured, with a clear emotional arc and a
# │              satisfying conclusion that hints at new beginnings. The themes
# │              of companionship, healing, and the transformative power of love
# │              are effectively conveyed, making it a compelling and heart
# │              warming read.
# ╚══════════════════════════════════════════════════════════════════════════════╝
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║ write_a_really_good_story(a dog)
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║ Prompt:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │      system: You are an expert novelist that writes in the style of
# │              Hemmingway. You write in lowercase.
# │
# │        user: Make a final revision of this story in your voice: The best
# │              draft is the first one. It presents a touching story of a
# │              scruffy shelter dog named Max who possesses a unique ability
# │              to sense emotions. The narrative explores the deep bond
# │              formed between Max and Henry, a grieving widower, and how
# │              Max's presence helps Henry heal and rediscover joy in life.
# │              The story is well-structured, with a clear emotional arc and
# │              a satisfying conclusion that hints at new beginnings. The
# │              themes of companionship, healing, and the transformative
# │              power of love are effectively conveyed, making it a
# │              compelling and heartwarming read..
# ╟──────────────────────────────────────────────────────────────────────────────╢
# ║ Output:
# ╟──────────────────────────────────────────────────────────────────────────────╢
# │   assistant: the story begins with max, a dog with ears that could
# │              hear the softest sorrow, and henry, a man whose heart was
# │              wrapped in the gray of mourning. max, with his scruffy fur and
# │              eyes deep as old wounds, lived in the shelter where the
# │              forgotten and the lost whispered among themselves. henry, whose
# │              love had slipped quietly from the world, walked in one day, his
# │              steps unsure, his eyes searching.
# │
# │              they met as two quiet souls, standing at the edge of
# │              their own silences. max, sensing the grief that hung on henry
# │              like a heavy coat, did not perform the antics the other dogs did
# │              to lure affection. instead, he sat, his gaze steady, his
# │              presence a gentle question. henry, feeling the unspoken
# │              understanding in the dog’s eyes, felt a flicker of warmth—a
# │              small, fluttering thing in the cold room of his heart.
# │
# │              the days that followed were simple. they were made of
# │              small moments: the soft thud of max’s tail on the floor, the
# │              slight smile on henry’s face as he watched the dog chase light
# │              across the wall. max taught henry the quiet joy of the present,
# │              the simple pleasure of a walk when the air was just turning to
# │              the crispness of fall, the silent comfort of sitting close, of
# │              touching a warm, living thing.
# │
# │              henry’s world, once dulled by grief, began to pulse
# │              with something that resembled hope. max, with every nudge of his
# │              nose, seemed to push away the heavy curtains of loss. together,
# │              they rediscovered the world. it was not the same as it had been;
# │              it was smaller, perhaps, and more fragile, but it was theirs.
# │
# │              the story ends not with a grand revelation, but with a
# │              quiet morning. henry and max, sitting on the porch, watch the
# │              sunrise paint the world golden. it hints at new beginnings, at
# │              days that would come filled with small joys and healing. it is a
# │              story of companionship, of the silent, steadfast love that can
# │              save us, and of the quiet bravery of continuing to find joy in a
# │              world that has known sorrow.
# ╚══════════════════════════════════════════════════════════════════════════════╝

# %%
ell.init(store='./logdir', autocommit=True, verbose=True)

# %%
import ell

ell.init(store='./logdir', autocommit=True)

@ell.simple(model="gpt-4o")
def hello(name: str):
    """You are a helpful assistant."""
    return f"Say hello to {name}!"

greeting = hello("Sam Altman")
print(greeting)
# Out:
# Hello, Sam Altman! How can I assist you today?
